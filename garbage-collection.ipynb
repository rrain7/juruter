// %% [markdown]
// # 垃圾回收

// %% [markdown]
// - C/C++ 存在一个问题：什么时候你应该释放你的内存？
//     - 在复杂的代码库中，很容易出现内存泄漏、二次释放或使用后释放等问题。
//
// - Rust: 使用精巧的类型系统来表示谁负责释放内存，并让编译器检查一切是否正确。
//     - 但仍然难以编程。
//     - 你需要不断地思考谁拥有什么所有权。
//
// - 更古老的方法：垃圾回收
//     - 在编写程序时，不必担心释放内存
//     - 运行程序时，运行时会观察何时不再使用内存，并为您释放它
//     - 例如，在 Python 中您永远不需要手动管理内存
